# %% [markdown]
# <h1>Assignment 1 — Inspecting a New Dataset

# %%
import pandas as pd
t = pd.read_csv('Titanic-Dataset.csv')

# %% [markdown]
# <h4>Q1 Load the dataset into t. How many rows and how many columns does it have?

# %%
t = pd.read_csv('Titanic-Dataset.csv')
print(t.shape)
# Out:
# (891, 12)

# %% [markdown]
# <h4>Q2 Print all the column names. Pick any three and write in a comment what you think each one holds.

# %%
print(t.columns)
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='str')

# %% [markdown]
# <h4>Q3 Display the first 7 rows and the last 3 rows.

# %%
t.head(7)
t.tail(3)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %% [markdown]
# <h4>Q4 Run t.info(). Some columns have fewer values than the total number of rows. Write down which
# columns those are, and how many values are missing from each. ★

# %%
t.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    str
#  4   Sex          891 non-null    str
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    str
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    str
#  11  Embarked     889 non-null    str
# dtypes: float64(2), int64(5), str(5)
# memory usage: 83.7 KB

# %% [markdown]
# <h4>Q5 Run t.describe(). It shows fewer columns than info() listed. Write down two columns it left out,
# and explain why.

# %%
t.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# <h4>Q6 For the class column, answer all three questions below using a different function for each:
# a) how many different values are there?
# b) what are they?
# c) how many passengers fall into each one?

# %%
t['Pclass'].nunique()
t['Pclass'].unique()
t['Pclass'].value_counts()
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %% [markdown]
# <h4>Q7 Find how many passengers were male and how many were female

# %%
t['Sex'].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %% [markdown]
# <h4>Q8 In describe(), look at the age column. Compare its mean with its 50% value. Which is larger, and
# what does that suggest about the passengers' ages? ★

# %%
t['Age'].describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %% [markdown]
# <h4>Q9 (Challenge) The age column has missing values. Using only shape and info(), work out what
# percentage of age values are missing. Write the number in a comment.

# %%
t.shape
t.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    str
#  4   Sex          891 non-null    str
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    str
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    str
#  11  Embarked     889 non-null    str
# dtypes: float64(2), int64(5), str(5)
# memory usage: 83.7 KB

# %%
t.groupby('Age')['Fare'].mean().round()
#Dataset mein jitne bhi log hain, unki  (Age) ke hisaab se unke ticket ka average (Fare) nikaalo aur use round-off(bina decimal ke) karke dikhao
# Out:
# Age
# 0.42       9.0
# 0.67      14.0
# 0.75      19.0
# 0.83      24.0
# 0.92     152.0
#          ...
# 70.00     41.0
# 70.50      8.0
# 71.00     42.0
# 74.00      8.0
# 80.00     30.0
# Name: Fare, Length: 88, dtype: float64

# %%
tip=pd.read_csv('tip.csv')
tip.groupby('day')['tip'].mean().round()
# Out:
# day
# Fri     3.0
# Sat     3.0
# Sun     3.0
# Thur    3.0
# Name: tip, dtype: float64

# %% [markdown]
# <h2>Find the day with the maximum tip

# %%
tip['tip_pct'] = (tip['tip'] / tip['total_bill'] * 100).round(2)
tip.groupby('day')['tip_pct'].mean().round(2)
# Out:
# day
# Fri     16.99
# Sat     15.31
# Sun     16.69
# Thur    16.13
# Name: tip_pct, dtype: float64

# %%
tip['tip_pct'] = (tip['tip'] / tip['total_bill'] * 100).round(2)
tip.groupby('size')['tip_pct'].mean().round(2)
# Out:
# size
# 1    21.73
# 2    16.57
# 3    15.21
# 4    14.59
# 5    14.15
# 6    15.62
# Name: tip_pct, dtype: float64

# %%
tip.groupby('size')['total_bill'].mean()
# Out:
# size
# 1     7.242500
# 2    16.448013
# 3    23.277632
# 4    28.613514
# 5    30.068000
# 6    34.830000
# Name: total_bill, dtype: float64

# %%
print(tip.groupby('day')['tip'].idxmax())
print(tip.groupby('day')['tip'].max())
# Out:
# day
# Fri      95
# Sat     170
# Sun     183
# Thur    141
# Name: tip, dtype: int64
# day
# Fri      4.73
# Sat     10.00
# Sun      6.50
# Thur     6.70
# Name: tip, dtype: float64

# %%
b=pd.read_csv('bookings.csv')
